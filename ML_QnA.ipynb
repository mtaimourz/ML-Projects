# %% [markdown]
# ## ML General Q/A

# %% [markdown]
# ## what is the meaning of overfitting and underfitting in terms of polynomial regression. Does overfitting and underfitting have a single defination that fits for other algorithms like gradient descent and its variants and linear lineargression.
#
# ![image.png](attachment:a6df2e06-ad7c-4aea-b3e9-8788429f3b42.png)

# %% [markdown]
# ## what is meaning of degree in polynomial regression. is the degree concept only limited to polynomial regression or it also fits for other algorithms
#
# ![image.png](attachment:3e954ba6-6e97-45bc-9703-7b00c0c40f52.png)
